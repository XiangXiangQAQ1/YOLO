# %%
"""
-------------------------------------------------------------------------------
File:        pytorch.py
Description: 示例脚本，演示pytorch加载YOLOv5模型并进行推理
Author:      傅文翔
Created:     2025-05-13
-------------------------------------------------------------------------------
Modification History:
Date        | By      | Version | Description
------------|---------|---------|-------------------------------
2025-05-13  | 傅文翔  | 1.0.0   | 初始创建
-------------------------------------------------------------------------------
"""


import torch

# Model loading
model = torch.hub.load("ultralytics/yolov5", "yolov5s")  # Can be 'yolov5n' - 'yolov5x6', or 'custom'

# Inference on images
img = "https://ultralytics.com/images/zidane.jpg"  # Can be a file, Path, PIL, OpenCV, numpy, or list of images

# Run inference
results = model(img)

# Display results
results.print()  # Other options: .show(), .save(), .crop(), .pandas(), etc. Explore these in the Predict mode documentation.
# Out:
# Using cache found in /root/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2025-5-13 Python-3.8.20 torch-2.4.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3090, 24154MiB)
#
# Downloading https://github.com/ultralytics/yolov5/releases/download/v7.0/yolov5s.pt to yolov5s.pt...
#   0%|          | 0.00/14.1M [02:40<?, ?B/s]
# ERROR: Downloaded file 'yolov5s.pt' does not exist or size is < min_bytes=100000.0
# yolov5s.pt missing, try downloading from https://github.com/ultralytics/yolov5/releases/v7.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 19
#      16 import torch
#      18 # Model loading
# ---> 19 model = torch.hub.load("ultralytics/yolov5", "yolov5s")  # Can be 'yolov5n' - 'yolov5x6', or 'custom'
#      21 # Inference on images
#      22 img = "https://ultralytics.com/images/zidane.jpg"  # Can be a file, Path, PIL, OpenCV, numpy, or list of images
#
# File /usr/local/anaconda3/envs/yolo/lib/python3.8/site-packages/torch/hub.py:570, in load(repo_or_dir, model, source, trust_repo, force_reload, verbose, skip_validation, *args, **kwargs)
#     566 if source == 'github':
#     567     repo_or_dir = _get_cache_or_reload(repo_or_dir, force_reload, trust_repo, "load",
#     568                                        verbose=verbose, skip_validation=skip_validation)
# --> 570 model = _load_local(repo_or_dir, model, *args, **kwargs)
#     571 return model
#
# File /usr/local/anaconda3/envs/yolo/lib/python3.8/site-packages/torch/hub.py:599, in _load_local(hubconf_dir, model, *args, **kwargs)
#     596     hub_module = _import_module(MODULE_HUBCONF, hubconf_path)
#     598     entry = _load_entry_from_hubconf(hub_module, model)
# --> 599     model = entry(*args, **kwargs)
#     601 return model
#
# File ~/.cache/torch/hub/ultralytics_yolov5_master/hubconf.py:216, in yolov5s(pretrained, channels, classes, autoshape, _verbose, device)
#     177 def yolov5s(pretrained=True, channels=3, classes=80, autoshape=True, _verbose=True, device=None):
#     178     """
#     179     Create a YOLOv5-small (yolov5s) model with options for pretraining, input channels, class count, autoshaping,
#     180     verbosity, and device configuration.
#    (...)
#     214         the [YOLOv5 PyTorch Hub Documentation](https://pytorch.org/hub/ultralytics_yolov5/).
#     215     """
# --> 216     return _create("yolov5s", pretrained, channels, classes, autoshape, _verbose, device)
#
# File ~/.cache/torch/hub/ultralytics_yolov5_master/hubconf.py:71, in _create(name, pretrained, channels, classes, autoshape, verbose, device)
#      69 if pretrained and channels == 3 and classes == 80:
#      70     try:
# ---> 71         model = DetectMultiBackend(path, device=device, fuse=autoshape)  # detection model
#      72         if autoshape:
#      73             if model.pt and isinstance(model.model, ClassificationModel):
#
# File ~/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:490, in DetectMultiBackend.__init__(self, weights, device, dnn, data, fp16, fuse)
#     487     w = attempt_download(w)  # download if not local
#     489 if pt:  # PyTorch
# --> 490     model = attempt_load(weights if isinstance(weights, list) else w, device=device, inplace=True, fuse=fuse)
#     491     stride = max(int(model.stride.max()), 32)  # model stride
#     492     names = model.module.names if hasattr(model, "module") else model.names  # get class names
#
# File ~/.cache/torch/hub/ultralytics_yolov5_master/models/experimental.py:99, in attempt_load(weights, device, inplace, fuse)
#      97 model = Ensemble()
#      98 for w in weights if isinstance(weights, list) else [weights]:
# ---> 99     ckpt = torch.load(attempt_download(w), map_location="cpu")  # load
#     100     ckpt = (ckpt.get("ema") or ckpt["model"]).to(device).float()  # FP32 model
#     102     # Model compatibility updates
#
# File ~/.cache/torch/hub/ultralytics_yolov5_master/utils/downloads.py:130, in attempt_download(file, repo, release)
#     128     if name in assets:
#     129         file.parent.mkdir(parents=True, exist_ok=True)  # make parent dir (if required)
# --> 130         safe_download(
#     131             file,
#     132             url=f"https://github.com/{repo}/releases/download/{tag}/{name}",
#     133             min_bytes=1e5,
#     134             error_msg=f"{file} missing, try downloading from https://github.com/{repo}/releases/{tag}",
#     135         )
#     137 return str(file)
#
# File ~/.cache/torch/hub/ultralytics_yolov5_master/utils/downloads.py:73, in safe_download(file, url, url2, min_bytes, error_msg)
#      71 try:  # url1
#      72     LOGGER.info(f"Downloading {url} to {file}...")
# ---> 73     torch.hub.download_url_to_file(url, str(file), progress=LOGGER.level <= logging.INFO)
#      74     assert file.exists() and file.stat().st_size > min_bytes, assert_msg  # check
#      75 except Exception as e:  # url2
#
# File /usr/local/anaconda3/envs/yolo/lib/python3.8/site-packages/torch/hub.py:655, in download_url_to_file(url, dst, hash_prefix, progress)
#     652 with tqdm(total=file_size, disable=not progress,
#     653           unit='B', unit_scale=True, unit_divisor=1024) as pbar:
#     654     while True:
# --> 655         buffer = u.read(READ_DATA_CHUNK)
#     656         if len(buffer) == 0:
#     657             break
#
# File /usr/local/anaconda3/envs/yolo/lib/python3.8/http/client.py:459, in HTTPResponse.read(self, amt)
#     456 if amt is not None:
#     457     # Amount is given, implement using readinto
#     458     b = bytearray(amt)
# --> 459     n = self.readinto(b)
#     460     return memoryview(b)[:n].tobytes()
#     461 else:
#     462     # Amount is not given (unbounded read) so we must check self.length
#     463     # and self.chunked
#
# File /usr/local/anaconda3/envs/yolo/lib/python3.8/http/client.py:503, in HTTPResponse.readinto(self, b)
#     498         b = memoryview(b)[0:self.length]
#     500 # we do not use _safe_read() here because this may be a .will_close
#     501 # connection, and the user is reading more bytes than will be provided
#     502 # (for example, reading in 1k chunks)
# --> 503 n = self.fp.readinto(b)
#     504 if not n and b:
#     505     # Ideally, we would raise IncompleteRead if the content-length
#     506     # wasn't satisfied, but it might break compatibility.
#     507     self._close_conn()
#
# File /usr/local/anaconda3/envs/yolo/lib/python3.8/socket.py:681, in SocketIO.readinto(self, b)
#     679 while True:
#     680     try:
# --> 681         return self._sock.recv_into(b)
#     682     except timeout:
#     683         self._timeout_occurred = True
#
# File /usr/local/anaconda3/envs/yolo/lib/python3.8/ssl.py:1274, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1270     if flags != 0:
#    1271         raise ValueError(
#    1272           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1273           self.__class__)
# -> 1274     return self.read(nbytes, buffer)
#    1275 else:
#    1276     return super().recv_into(buffer, nbytes, flags)
#
# File /usr/local/anaconda3/envs/yolo/lib/python3.8/ssl.py:1132, in SSLSocket.read(self, len, buffer)
#    1130 try:
#    1131     if buffer is not None:
# -> 1132         return self._sslobj.read(len, buffer)
#    1133     else:
#    1134         return self._sslobj.read(len)
#
# KeyboardInterrupt:
